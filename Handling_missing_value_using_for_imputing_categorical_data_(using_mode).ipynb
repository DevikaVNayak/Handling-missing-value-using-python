# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv('/content/movies.csv')

# %%
dataset.isnull().sum()
# Out:
# index                      0
# budget                     0
# genres                    28
# homepage                3091
# id                         0
# keywords                 412
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# cast                      43
# crew                       0
# director                  30
# dtype: int64

# %%
dataset.tail(10)
# Out:
#       index  budget                          genres  \
# 4793   4793       0                           Drama
# 4794   4794       0          Thriller Horror Comedy
# 4795   4795       0                           Drama
# 4796   4796    7000  Science Fiction Drama Thriller
# 4797   4797       0                Foreign Thriller
# 4798   4798  220000           Action Crime Thriller
# 4799   4799    9000                  Comedy Romance
# 4800   4800       0   Comedy Drama Romance TV Movie
# 4801   4801       0                             NaN
# 4802   4802       0                     Documentary
#
#                                                homepage      id  \
# 4793                                                NaN  182291
# 4794                                                NaN  286939
# 4795                                                NaN  124606
# 4796                         http://www.primermovie.com   14337
# 4797                                                NaN   67238
# ...

# %%
dataset.fillna(method='ffill')#previous value replaces NaN
dataset.fillna(method='bfill')#next value replaces Nan for nummerial data
# Out:
# <ipython-input-11-48d03a9f64c1>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dataset.fillna(method='bfill')
#       index     budget                                    genres  \
# 0         0  237000000  Action Adventure Fantasy Science Fiction
# 1         1  300000000                  Adventure Fantasy Action
# 2         2  245000000                    Action Adventure Crime
# 3         3  250000000               Action Crime Drama Thriller
# 4         4  260000000          Action Adventure Science Fiction
# ...     ...        ...                                       ...
# 4798   4798     220000                     Action Crime Thriller
# 4799   4799       9000                            Comedy Romance
# 4800   4800          0             Comedy Drama Romance TV Movie
# 4801   4801          0                               Documentary
# ...

# %%
dataset.select_dtypes(include='object').isnull().sum()
# Out:
# genres                    28
# homepage                3091
# keywords                 412
# original_language          0
# original_title             0
# overview                   3
# production_companies       0
# production_countries       0
# release_date               1
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# cast                      43
# crew                       0
# director                  30
# dtype: int64

# %%
for i in dataset.select_dtypes(include='object').columns:
  print(i)
# Out:
# genres
# homepage
# keywords
# original_language
# original_title
# overview
# production_companies
# production_countries
# release_date
# spoken_languages
# status
# tagline
# title
# cast
# crew
# director

# %%
for i  in dataset.select_dtypes(include='object').columns:
   dataset[i].fillna(dataset[i].mode()[0],inplace=True)
# Out:
# <ipython-input-16-0f2138208e06>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset[i].fillna(dataset[i].mode()[0],inplace=True)

# %%
dataset.isnull().sum()
# Out:
# index                   0
# budget                  0
# genres                  0
# homepage                0
# id                      0
# keywords                0
# original_language       0
# original_title          0
# overview                0
# popularity              0
# production_companies    0
# production_countries    0
# release_date            0
# revenue                 0
# runtime                 2
# spoken_languages        0
# status                  0
# tagline                 0
# title                   0
# vote_average            0
# vote_count              0
# cast                    0
# crew                    0
# director                0
# dtype: int64
